# %%
# !pip install imageai
# Out:
# Requirement already satisfied: imageai in /usr/local/lib/python3.10/dist-packages (3.0.3)

# %%
from google.colab import drive
from imageai.Detection import VideoObjectDetection
import os
import cv2

# %%
dataset_name="UCSD"
'Update the dataset name with UMN, UCSD, Ped1, Ped2, BOSS, Ours'
# Out:
# 'Update the dataset name with UMN, UCSD, Ped1, Ped2, BOSS, Ours'

# %%
drive.mount('/content/drive',force_remount=True)

file = "/content/drive" + "/My Drive/" + "minorproject2/"+dataset_name + "/"
print (file)
# Out:
# /usr/lib/python3.10/threading.py:957: ResourceWarning: unclosed file <_io.FileIO name=46 mode='wb' closefd=True>
#   del self._target, self._args, self._kwargs
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /usr/lib/python3.10/threading.py:957: ResourceWarning: unclosed file <_io.FileIO name=47 mode='rb' closefd=True>
#   del self._target, self._args, self._kwargs
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# sys:1: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7cbc220a0f40>
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# Mounted at /content/drive
# /content/drive/My Drive/minorproject2/UCSD/

# %%
def forMinute(minute_number, output_arrays, count_arrays, average_output_count):
    print("MINUTE : ", minute_number)
    print("Array for the outputs of each frame ", output_arrays)
    print("Array for output count for unique objects in each frame : ", count_arrays)
    print("Output average count for unique objects in the last minute: ", average_output_count)
    print("------------END OF A MINUTE --------------")

# %%
def forSeconds(second_number, output_arrays, count_arrays, average_output_count):
    print("SECOND : ", second_number)
    print("Array for the outputs of each frame ", output_arrays)
    print("Array for output count for unique objects in each frame : ", count_arrays)
    print("Output average count for unique objects in the last second: ", average_output_count)
    print("------------END OF A SECOND --------------")

# %%
detector = VideoObjectDetection()
detector.setModelTypeAsRetinaNet()
execution_path = "/content/drive" + "/My Drive/" + "minorproject2/"
new_path = execution_path + "retinanet_resnet50_fpn_coco-eeacb38b.pth"
print (new_path)
detector.setModelPath(new_path)
#detector.setModelPath(os.path.join(execution_path , "retinanet_resnet50_fpn_coco-eeacb38b.pth"))
detector.loadModel()
# Out:
# /content/drive/My Drive/minorproject2/retinanet_resnet50_fpn_coco-eeacb38b.pth

# %%
drive.mount('/content/drive',force_remount=True)
# Out:
# /usr/lib/python3.10/threading.py:957: ResourceWarning: unclosed file <_io.FileIO name=38 mode='wb' closefd=True>
#   del self._target, self._args, self._kwargs
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /usr/lib/python3.10/threading.py:957: ResourceWarning: unclosed file <_io.FileIO name=39 mode='rb' closefd=True>
#   del self._target, self._args, self._kwargs
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# sys:1: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7cbc261e7a00>
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# Mounted at /content/drive

# %%
for i in (1,5):
  temp = str(i) + ".mp4"
  outtemp = file+"/output/"+temp
  path = file
  detector.detectObjectsFromVideo(
    input_file_path=os.path.join(path, temp),
    output_file_path=os.path.join(outtemp, temp),
    frames_per_second=1,
    per_minute_function=forMinute,
    per_second_function=forSeconds,
    minimum_percentage_probability=30
  )
# Out:
# SECOND :  2
# Array for the outputs of each frame  [[{'name': 'car', 'percentage_probability': 90.7, 'box_points': [122, 53, 206, 100]}, {'name': 'person', 'percentage_probability': 78.88, 'box_points': [217, 52, 226, 76]}]]
# Array for output count for unique objects in each frame :  [{'car': 1, 'person': 1}]
# Output average count for unique objects in the last second:  {'car': 1, 'person': 1}
# ------------END OF A SECOND --------------
# SECOND :  3
# Array for the outputs of each frame  [[{'name': 'car', 'percentage_probability': 90.76, 'box_points': [122, 53, 207, 100]}, {'name': 'person', 'percentage_probability': 76.79, 'box_points': [216, 51, 226, 76]}]]
# Array for output count for unique objects in each frame :  [{'car': 1, 'person': 1}]
# Output average count for unique objects in the last second:  {'car': 1, 'person': 1}
# ------------END OF A SECOND --------------
# SECOND :  4
# Array for the outputs of each frame  [[{'name': 'car', 'percentage_probability': 89.42, 'box_points': [122, 54, 207, 101]}, {'name': 'person', 'percentage_probability': 68.88, 'box_points': [220, 50, 229, 74]}]]
# Array for output count for unique objects in each frame :  [{'car': 1, 'person': 1}]
# Output average count for unique objects in the last second:  {'car': 1, 'person': 1}
# ------------END OF A SECOND --------------
# SECOND :  5
# Array for the outputs of each frame  [[{'name': 'car', 'percentage_probability': 89.04, 'box_points': [121, 54, 206, 101]}, {'name': 'person', 'percentage_probability': 80.92, 'box_points': [221, 50, 231, 73]}]]
# Array for output count for unique objects in each frame :  [{'car': 1, 'person': 1}]
# Output average count for unique objects in the last second:  {'car': 1, 'person': 1}
# ------------END OF A SECOND --------------
# SECOND :  6
# Array for the outputs of each frame  [[{'name': 'car', 'percentage_probability': 88.64, 'box_points': [121, 54, 207, 101]}, {'name': 'person', 'percentage_probability': 84.87, 'box_points': [223, 49, 233, 72]}]]
# Array for output count for unique objects in each frame :  [{'car': 1, 'person': 1}]
# Output average count for unique objects in the last second:  {'car': 1, 'person': 1}
# ------------END OF A SECOND --------------
# SECOND :  7
# Array for the outputs of each frame  [[{'name': 'car', 'percentage_probability': 87.06, 'box_points': [121, 54, 207, 101]}, {'name': 'person', 'percentage_probability': 79.73, 'box_points': [225, 50, 233, 72]}, {'name': 'car', 'percentage_probability': 57.61, 'box_points': [260, 46, 272, 65]}]]
# Array for output count for unique objects in each frame :  [{'car': 2, 'person': 1}]
# Output average count for unique objects in the last second:  {'car': 2, 'person': 1}
# ------------END OF A SECOND --------------
# SECOND :  8
# Array for the outputs of each frame  [[{'name': 'car', 'percentage_probability': 88.61, 'box_points': [121, 55, 207, 101]}, {'name': 'person', 'percentage_probability': 61.16, 'box_points': [225, 49, 233, 71]}, {'name': 'car', 'percentage_probability': 53.53, 'box_points': [260, 45, 272, 65]}]]
# Array for output count for unique objects in each frame :  [{'car': 2, 'person': 1}]
# Output average count for unique objects in the last second:  {'car': 2, 'person': 1}
# ------------END OF A SECOND --------------
# SECOND :  9
# Array for the outputs of each frame  [[{'name': 'car', 'percentage_probability': 89.02, 'box_points': [122, 54, 207, 100]}, {'name': 'person', 'percentage_probability': 69.74, 'box_points': [225, 49, 233, 71]}, {'name': 'car', 'percentage_probability': 62.96, 'box_points': [259, 46, 272, 67]}]]
# Array for output count for unique objects in each frame :  [{'car': 2, 'person': 1}]
# Output average count for unique objects in the last second:  {'car': 2, 'person': 1}
# ------------END OF A SECOND --------------
# SECOND :  10
# Array for the outputs of each frame  [[{'name': 'car', 'percentage_probability': 90.94, 'box_points': [121, 53, 207, 101]}, {'name': 'person', 'percentage_probability': 75.87, 'box_points': [225, 49, 233, 71]}, {'name': 'car', 'percentage_probability': 67.0, 'box_points': [257, 46, 272, 67]}]]
# Array for output count for unique objects in each frame :  [{'car': 2, 'person': 1}]
# Output average count for unique objects in the last second:  {'car': 2, 'person': 1}
# ------------END OF A SECOND --------------
# SECOND :  11
# Array for the outputs of each frame  [[{'name': 'car', 'percentage_probability': 90.87, 'box_points': [121, 54, 207, 101]}, {'name': 'person', 'percentage_probability': 79.89, 'box_points': [226, 49, 233, 70]}, {'name': 'car', 'percentage_probability': 72.96, 'box_points': [256, 45, 272, 69]}]]
# Array for output count for unique objects in each frame :  [{'car': 2, 'person': 1}]
# Output average count for unique objects in the last second:  {'car': 2, 'person': 1}
# ------------END OF A SECOND --------------
# SECOND :  12
# Array for the outputs of each frame  [[{'name': 'car', 'percentage_probability': 90.5, 'box_points': [121, 54, 207, 101]}, {'name': 'person', 'percentage_probability': 76.73, 'box_points': [225, 46, 236, 71]}, {'name': 'car', 'percentage_probability': 57.37, 'box_points': [254, 47, 272, 71]}]]
# Array for output count for unique objects in each frame :  [{'car': 2, 'person': 1}]
# Output average count for unique objects in the last second:  {'car': 2, 'person': 1}
# ------------END OF A SECOND --------------
# SECOND :  13
# Array for the outputs of each frame  [[{'name': 'car', 'percentage_probability': 91.03, 'box_points': [121, 53, 207, 101]}, {'name': 'person', 'percentage_probability': 82.45, 'box_points': [226, 47, 236, 70]}, {'name': 'car', 'percentage_probability': 66.96, 'box_points': [251, 44, 276, 75]}]]
# Array for output count for unique objects in each frame :  [{'car': 2, 'person': 1}]
# Output average count for unique objects in the last second:  {'car': 2, 'person': 1}
# ------------END OF A SECOND --------------
# SECOND :  14
# Array for the outputs of each frame  [[{'name': 'car', 'percentage_probability': 89.75, 'box_points': [121, 54, 207, 101]}, {'name': 'person', 'percentage_probability': 82.17, 'box_points': [227, 46, 238, 70]}, {'name': 'car', 'percentage_probability': 64.88, 'box_points': [248, 48, 284, 77]}, {'name': 'person', 'percentage_probability': 52.54, 'box_points': [240, 45, 250, 61]}]]
# Array for output count for unique objects in each frame :  [{'car': 2, 'person': 2}]
# Output average count for unique objects in the last second:  {'car': 2, 'person': 2}
# ------------END OF A SECOND --------------
# SECOND :  15
# Array for the outputs of each frame  [[{'name': 'car', 'percentage_probability': 88.55, 'box_points': [121, 54, 207, 101]}, {'name': 'person', 'percentage_probability': 75.97, 'box_points': [230, 46, 238, 68]}, {'name': 'car', 'percentage_probability': 62.48, 'box_points': [243, 45, 293, 85]}]]
# Array for output count for unique objects in each frame :  [{'car': 2, 'person': 1}]
# Output average count for unique objects in the last second:  {'car': 2, 'person': 1}
# ------------END OF A SECOND --------------
# SECOND :  16
# Array for the outputs of each frame  [[{'name': 'car', 'percentage_probability': 88.23, 'box_points': [121, 54, 207, 101]}, {'name': 'person', 'percentage_probability': 77.97, 'box_points': [231, 47, 240, 68]}, {'name': 'car', 'percentage_probability': 63.08, 'box_points': [240, 44, 298, 94]}]]
# Array for output count for unique objects in each frame :  [{'car': 2, 'person': 1}]
# Output average count for unique objects in the last second:  {'car': 2, 'person': 1}
# ------------END OF A SECOND --------------
# SECOND :  17
# Array for the outputs of each frame  [[{'name': 'car', 'percentage_probability': 89.21, 'box_points': [121, 54, 207, 101]}, {'name': 'car', 'percentage_probability': 57.42, 'box_points': [235, 46, 270, 87]}, {'name': 'car', 'percentage_probability': 54.1, 'box_points': [274, 64, 299, 101]}, {'name': 'person', 'percentage_probability': 51.8, 'box_points': [231, 47, 242, 67]}]]
# Array for output count for unique objects in each frame :  [{'car': 3, 'person': 1}]
# Output average count for unique objects in the last second:  {'car': 3, 'person': 1}
# ------------END OF A SECOND --------------
# SECOND :  18
# Array for the outputs of each frame  [[{'name': 'car', 'percentage_probability': 89.01, 'box_points': [121, 54, 207, 101]}, {'name': 'car', 'percentage_probability': 67.28, 'box_points': [275, 65, 302, 104]}, {'name': 'car', 'percentage_probability': 65.23, 'box_points': [232, 55, 267, 92]}, {'name': 'mouse', 'percentage_probability': 65.19, 'box_points': [21, 119, 192, 209]}]]
# Array for output count for unique objects in each frame :  [{'car': 3, 'mouse': 1}]
# Output average count for unique objects in the last second:  {'car': 3, 'mouse': 1}
# ------------END OF A SECOND --------------
# SECOND :  19
# Array for the outputs of each frame  [[{'name': 'car', 'percentage_probability': 86.27, 'box_points': [121, 54, 207, 99]}, {'name': 'car', 'percentage_probability': 68.09, 'box_points': [230, 56, 267, 92]}, {'name': 'car', 'percentage_probability': 60.4, 'box_points': [274, 66, 303, 107]}, {'name': 'cell phone', 'percentage_probability': 56.57, 'box_points': [88, 95, 228, 198]}, {'name': 'mouse', 'percentage_probability': 55.6, 'box_points': [89, 95, 228, 197]}]]
# Array for output count for unique objects in each frame :  [{'car': 3, 'cell phone': 1, 'mouse': 1}]
# Output average count for unique objects in the last second:  {'car': 3, 'cell phone': 1, 'mouse': 1}
# ------------END OF A SECOND --------------
# SECOND :  20
# Array for the outputs of each frame  [[{'name': 'car', 'percentage_probability': 82.28, 'box_points': [121, 54, 207, 100]}, {'name': 'car', 'percentage_probability': 81.74, 'box_points': [137, 85, 246, 161]}, {'name': 'car', 'percentage_probability': 75.33, 'box_points': [273, 65, 303, 108]}, {'name': 'car', 'percentage_probability': 62.77, 'box_points': [230, 55, 267, 92]}]]
# Array for output count for unique objects in each frame :  [{'car': 4}]
# Output average count for unique objects in the last second:  {'car': 4}
# ------------END OF A SECOND --------------
# SECOND :  21
# Array for the outputs of each frame  [[{'name': 'car', 'percentage_probability': 87.35, 'box_points': [168, 78, 256, 139]}, {'name': 'car', 'percentage_probability': 85.34, 'box_points': [120, 53, 207, 100]}]]
# Array for output count for unique objects in each frame :  [{'car': 2}]
# Output average count for unique objects in the last second:  {'car': 2}
# ------------END OF A SECOND --------------
# SECOND :  22
# Array for the outputs of each frame  [[{'name': 'car', 'percentage_probability': 84.37, 'box_points': [121, 54, 207, 101]}, {'name': 'car', 'percentage_probability': 81.4, 'box_points': [176, 76, 261, 134]}]]
# Array for output count for unique objects in each frame :  [{'car': 2}]
# Output average count for unique objects in the last second:  {'car': 2}
# ------------END OF A SECOND --------------
# SECOND :  23
# Array for the outputs of each frame  [[{'name': 'car', 'percentage_probability': 86.35, 'box_points': [121, 54, 207, 101]}, {'name': 'car', 'percentage_probability': 80.05, 'box_points': [174, 74, 263, 136]}]]
# Array for output count for unique objects in each frame :  [{'car': 2}]
# Output average count for unique objects in the last second:  {'car': 2}
# ------------END OF A SECOND --------------
# SECOND :  24
# Array for the outputs of each frame  [[{'name': 'car', 'percentage_probability': 86.42, 'box_points': [121, 53, 207, 101]}, {'name': 'car', 'percentage_probability': 81.35, 'box_points': [174, 75, 262, 136]}, {'name': 'motorcycle', 'percentage_probability': 58.59, 'box_points': [35, 124, 109, 203]}, {'name': 'person', 'percentage_probability': 57.11, 'box_points': [48, 117, 62, 138]}]]
# Array for output count for unique objects in each frame :  [{'car': 2, 'motorcycle': 1, 'person': 1}]
# Output average count for unique objects in the last second:  {'car': 2, 'motorcycle': 1, 'person': 1}
# ------------END OF A SECOND --------------
# SECOND :  25
# Array for the outputs of each frame  [[{'name': 'motorcycle', 'percentage_probability': 83.23, 'box_points': [112, 87, 157, 145]}, {'name': 'car', 'percentage_probability': 80.66, 'box_points': [176, 76, 261, 136]}, {'name': 'car', 'percentage_probability': 66.97, 'box_points': [120, 53, 208, 102]}]]
# Array for output count for unique objects in each frame :  [{'motorcycle': 1, 'car': 2}]
# Output average count for unique objects in the last second:  {'motorcycle': 1, 'car': 2}
# ------------END OF A SECOND --------------
# SECOND :  26
# Array for the outputs of each frame  [[{'name': 'car', 'percentage_probability': 83.99, 'box_points': [176, 77, 260, 136]}, {'name': 'car', 'percentage_probability': 77.14, 'box_points': [125, 53, 206, 95]}, {'name': 'motorcycle', 'percentage_probability': 69.51, 'box_points': [143, 82, 177, 123]}]]
# Array for output count for unique objects in each frame :  [{'car': 2, 'motorcycle': 1}]
# Output average count for unique objects in the last second:  {'car': 2, 'motorcycle': 1}
# ------------END OF A SECOND --------------
# SECOND :  27
# Array for the outputs of each frame  [[{'name': 'car', 'percentage_probability': 79.61, 'box_points': [175, 76, 261, 136]}, {'name': 'motorcycle', 'percentage_probability': 69.23, 'box_points': [43, 118, 105, 190]}, {'name': 'car', 'percentage_probability': 61.03, 'box_points': [122, 63, 173, 100]}, {'name': 'car', 'percentage_probability': 60.71, 'box_points': [128, 55, 199, 99]}, {'name': 'car', 'percentage_probability': 50.92, 'box_points': [141, 53, 207, 84]}]]
# Array for output count for unique objects in each frame :  [{'car': 4, 'motorcycle': 1}]
# Output average count for unique objects in the last second:  {'car': 4, 'motorcycle': 1}
# ------------END OF A SECOND --------------
# SECOND :  28
# Array for the outputs of each frame  [[{'name': 'car', 'percentage_probability': 84.6, 'box_points': [176, 77, 260, 136]}, {'name': 'motorcycle', 'percentage_probability': 76.56, 'box_points': [93, 104, 138, 154]}, {'name': 'car', 'percentage_probability': 66.78, 'box_points': [122, 63, 183, 100]}, {'name': 'person', 'percentage_probability': 53.81, 'box_points': [101, 89, 140, 145]}]]
# Array for output count for unique objects in each frame :  [{'car': 2, 'motorcycle': 1, 'person': 1}]
# Output average count for unique objects in the last second:  {'car': 2, 'motorcycle': 1, 'person': 1}
# ------------END OF A SECOND --------------
# SECOND :  29
# Array for the outputs of each frame  [[{'name': 'car', 'percentage_probability': 85.03, 'box_points': [176, 77, 260, 136]}, {'name': 'motorcycle', 'percentage_probability': 69.57, 'box_points': [125, 96, 155, 131]}, {'name': 'motorcycle', 'percentage_probability': 58.15, 'box_points': [124, 81, 167, 131]}]]
# Array for output count for unique objects in each frame :  [{'car': 1, 'motorcycle': 2}]
# Output average count for unique objects in the last second:  {'car': 1, 'motorcycle': 2}
# ------------END OF A SECOND --------------
# SECOND :  30
# Array for the outputs of each frame  [[{'name': 'car', 'percentage_probability': 83.88, 'box_points': [176, 76, 260, 136]}, {'name': 'motorcycle', 'percentage_probability': 69.92, 'box_points': [132, 85, 171, 127]}, {'name': 'motorcycle', 'percentage_probability': 54.82, 'box_points': [147, 83, 171, 119]}]]
# Array for output count for unique objects in each frame :  [{'car': 1, 'motorcycle': 2}]
# Output average count for unique objects in the last second:  {'car': 1, 'motorcycle': 2}
# ------------END OF A SECOND --------------
# SECOND :  31
# Array for the outputs of each frame  [[{'name': 'car', 'percentage_probability': 75.69, 'box_points': [165, 80, 254, 142]}, {'name': 'motorcycle', 'percentage_probability': 61.03, 'box_points': [134, 92, 159, 126]}, {'name': 'cell phone', 'percentage_probability': 52.55, 'box_points': [165, 79, 254, 142]}]]
# Array for output count for unique objects in each frame :  [{'car': 1, 'motorcycle': 1, 'cell phone': 1}]
# Output average count for unique objects in the last second:  {'car': 1, 'motorcycle': 1, 'cell phone': 1}
# ------------END OF A SECOND --------------
# SECOND :  32
# Array for the outputs of each frame  [[{'name': 'person', 'percentage_probability': 78.96, 'box_points': [113, 66, 139, 112]}, {'name': 'car', 'percentage_probability': 70.59, 'box_points': [135, 84, 247, 158]}, {'name': 'car', 'percentage_probability': 67.69, 'box_points': [231, 55, 267, 91]}, {'name': 'motorcycle', 'percentage_probability': 62.49, 'box_points': [127, 89, 146, 126]}]]
# Array for output count for unique objects in each frame :  [{'person': 1, 'car': 2, 'motorcycle': 1}]
# Output average count for unique objects in the last second:  {'person': 1, 'car': 2, 'motorcycle': 1}
# ------------END OF A SECOND --------------
# SECOND :  33
# Array for the outputs of each frame  [[{'name': 'person', 'percentage_probability': 84.26, 'box_points': [3, 124, 43, 187]}, {'name': 'motorcycle', 'percentage_probability': 69.91, 'box_points': [170, 59, 213, 102]}, {'name': 'motorcycle', 'percentage_probability': 69.1, 'box_points': [1, 146, 63, 192]}, {'name': 'car', 'percentage_probability': 67.91, 'box_points': [231, 56, 267, 91]}, {'name': 'car', 'percentage_probability': 64.79, 'box_points': [69, 102, 220, 206]}, {'name': 'person', 'percentage_probability': 59.2, 'box_points': [100, 73, 137, 118]}, {'name': 'car', 'percentage_probability': 52.89, 'box_points': [272, 66, 302, 107]}]]
# Array for output count for unique objects in each frame :  [{'person': 2, 'motorcycle': 2, 'car': 3}]
# Output average count for unique objects in the last second:  {'person': 2, 'motorcycle': 2, 'car': 3}
# ------------END OF A SECOND --------------
# SECOND :  34
# Array for the outputs of each frame  [[{'name': 'motorcycle', 'percentage_probability': 72.3, 'box_points': [128, 83, 167, 126]}, {'name': 'car', 'percentage_probability': 70.2, 'box_points': [231, 56, 267, 91]}, {'name': 'person', 'percentage_probability': 66.22, 'box_points': [1, 113, 47, 164]}, {'name': 'motorcycle', 'percentage_probability': 64.79, 'box_points': [167, 58, 213, 102]}, {'name': 'motorcycle', 'percentage_probability': 57.92, 'box_points': [139, 86, 168, 115]}, {'name': 'person', 'percentage_probability': 55.57, 'box_points': [100, 71, 120, 116]}, {'name': 'car', 'percentage_probability': 52.41, 'box_points': [0, 114, 177, 209]}]]
# Array for output count for unique objects in each frame :  [{'motorcycle': 3, 'car': 2, 'person': 2}]
# Output average count for unique objects in the last second:  {'motorcycle': 3, 'car': 2, 'person': 2}
# ------------END OF A SECOND --------------
# SECOND :  35
# Array for the outputs of each frame  [[{'name': 'person', 'percentage_probability': 81.13, 'box_points': [91, 66, 116, 118]}, {'name': 'motorcycle', 'percentage_probability': 80.78, 'box_points': [2, 134, 56, 183]}, {'name': 'motorcycle', 'percentage_probability': 77.98, 'box_points': [113, 82, 160, 128]}, {'name': 'car', 'percentage_probability': 68.61, 'box_points': [231, 56, 267, 91]}, {'name': 'motorcycle', 'percentage_probability': 61.03, 'box_points': [177, 65, 214, 102]}, {'name': 'car', 'percentage_probability': 55.05, 'box_points': [272, 66, 302, 108]}, {'name': 'person', 'percentage_probability': 51.96, 'box_points': [1, 103, 35, 157]}, {'name': 'motorcycle', 'percentage_probability': 51.89, 'box_points': [131, 85, 167, 115]}]]
# Array for output count for unique objects in each frame :  [{'person': 2, 'motorcycle': 4, 'car': 2}]
# Output average count for unique objects in the last second:  {'person': 2, 'motorcycle': 4, 'car': 2}
# ------------END OF A SECOND --------------
# SECOND :  36
# Array for the outputs of each frame  [[{'name': 'person', 'percentage_probability': 90.38, 'box_points': [85, 70, 108, 122]}, {'name': 'motorcycle', 'percentage_probability': 87.85, 'box_points': [1, 129, 58, 184]}, {'name': 'motorcycle', 'percentage_probability': 74.87, 'box_points': [112, 87, 161, 127]}, {'name': 'person', 'percentage_probability': 70.1, 'box_points': [108, 68, 129, 107]}, {'name': 'motorcycle', 'percentage_probability': 67.69, 'box_points': [177, 61, 213, 102]}, {'name': 'car', 'percentage_probability': 66.62, 'box_points': [230, 56, 267, 92]}, {'name': 'car', 'percentage_probability': 62.16, 'box_points': [124, 63, 183, 99]}]]
# Array for output count for unique objects in each frame :  [{'person': 2, 'motorcycle': 3, 'car': 2}]
# Output average count for unique objects in the last second:  {'person': 2, 'motorcycle': 3, 'car': 2}
# ------------END OF A SECOND --------------
# SECOND :  37
# Array for the outputs of each frame  [[{'name': 'motorcycle', 'percentage_probability': 77.87, 'box_points': [116, 86, 165, 127]}, {'name': 'person', 'percentage_probability': 72.63, 'box_points': [94, 71, 116, 118]}, {'name': 'car', 'percentage_probability': 70.94, 'box_points': [231, 56, 267, 92]}, {'name': 'person', 'percentage_probability': 69.17, 'box_points': [77, 84, 107, 150]}, {'name': 'motorcycle', 'percentage_probability': 69.11, 'box_points': [6, 113, 62, 186]}, {'name': 'motorcycle', 'percentage_probability': 65.51, 'box_points': [177, 60, 214, 102]}, {'name': 'car', 'percentage_probability': 60.2, 'box_points': [123, 61, 190, 99]}, {'name': 'car', 'percentage_probability': 56.44, 'box_points': [273, 65, 302, 106]}]]
# Array for output count for unique objects in each frame :  [{'motorcycle': 3, 'person': 2, 'car': 3}]
# Output average count for unique objects in the last second:  {'motorcycle': 3, 'person': 2, 'car': 3}
# ------------END OF A SECOND --------------
# SECOND :  38
# Array for the outputs of each frame  [[{'name': 'person', 'percentage_probability': 84.48, 'box_points': [67, 96, 104, 172]}, {'name': 'motorcycle', 'percentage_probability': 81.52, 'box_points': [111, 88, 164, 128]}, {'name': 'person', 'percentage_probability': 75.27, 'box_points': [89, 77, 115, 128]}, {'name': 'car', 'percentage_probability': 67.93, 'box_points': [231, 56, 267, 92]}, {'name': 'motorcycle', 'percentage_probability': 65.97, 'box_points': [10, 138, 57, 187]}, {'name': 'car', 'percentage_probability': 65.13, 'box_points': [121, 63, 182, 99]}, {'name': 'person', 'percentage_probability': 64.5, 'box_points': [32, 114, 82, 182]}, {'name': 'car', 'percentage_probability': 56.95, 'box_points': [273, 65, 303, 106]}, {'name': 'motorcycle', 'percentage_probability': 54.38, 'box_points': [175, 62, 214, 102]}, {'name': 'car', 'percentage_probability': 54.01, 'box_points': [135, 58, 205, 100]}]]
# Array for output count for unique objects in each frame :  [{'person': 3, 'motorcycle': 3, 'car': 4}]
# Output average count for unique objects in the last second:  {'person': 3, 'motorcycle': 3, 'car': 4}
# ------------END OF A SECOND --------------
# SECOND :  39
# Array for the outputs of each frame  [[{'name': 'person', 'percentage_probability': 95.25, 'box_points': [61, 129, 118, 208]}, {'name': 'person', 'percentage_probability': 89.4, 'box_points': [80, 85, 110, 147]}, {'name': 'motorcycle', 'percentage_probability': 77.26, 'box_points': [111, 85, 165, 127]}, {'name': 'motorcycle', 'percentage_probability': 76.55, 'box_points': [181, 68, 215, 103]}, {'name': 'car', 'percentage_probability': 69.58, 'box_points': [231, 56, 267, 92]}, {'name': 'motorcycle', 'percentage_probability': 68.82, 'box_points': [1, 121, 73, 210]}, {'name': 'car', 'percentage_probability': 65.79, 'box_points': [122, 59, 190, 100]}, {'name': 'car', 'percentage_probability': 53.07, 'box_points': [273, 65, 302, 106]}]]
# Array for output count for unique objects in each frame :  [{'person': 2, 'motorcycle': 3, 'car': 3}]
# Output average count for unique objects in the last second:  {'person': 2, 'motorcycle': 3, 'car': 3}
# ------------END OF A SECOND --------------
# SECOND :  40
# Array for the outputs of each frame  [[{'name': 'person', 'percentage_probability': 89.27, 'box_points': [74, 108, 105, 163]}, {'name': 'motorcycle', 'percentage_probability': 77.13, 'box_points': [113, 86, 165, 128]}, {'name': 'motorcycle', 'percentage_probability': 76.26, 'box_points': [182, 69, 216, 103]}, {'name': 'car', 'percentage_probability': 74.65, 'box_points': [231, 56, 267, 92]}, {'name': 'car', 'percentage_probability': 63.54, 'box_points': [121, 55, 200, 100]}, {'name': 'motorcycle', 'percentage_probability': 62.5, 'box_points': [5, 124, 64, 188]}]]
# Array for output count for unique objects in each frame :  [{'person': 1, 'motorcycle': 3, 'car': 2}]
# Output average count for unique objects in the last second:  {'person': 1, 'motorcycle': 3, 'car': 2}
# ------------END OF A SECOND --------------
# SECOND :  41
# Array for the outputs of each frame  [[{'name': 'motorcycle', 'percentage_probability': 74.75, 'box_points': [113, 86, 165, 128]}, {'name': 'motorcycle', 'percentage_probability': 73.34, 'box_points': [2, 120, 65, 208]}, {'name': 'car', 'percentage_probability': 69.16, 'box_points': [230, 56, 267, 92]}, {'name': 'car', 'percentage_probability': 65.47, 'box_points': [121, 57, 193, 100]}, {'name': 'car', 'percentage_probability': 53.86, 'box_points': [273, 66, 303, 106]}, {'name': 'motorcycle', 'percentage_probability': 51.39, 'box_points': [182, 64, 216, 107]}]]
# Array for output count for unique objects in each frame :  [{'motorcycle': 3, 'car': 3}]
# Output average count for unique objects in the last second:  {'motorcycle': 3, 'car': 3}
# ------------END OF A SECOND --------------
# SECOND :  42
# Array for the outputs of each frame  [[{'name': 'motorcycle', 'percentage_probability': 73.82, 'box_points': [113, 86, 165, 128]}, {'name': 'motorcycle', 'percentage_probability': 71.14, 'box_points': [14, 121, 62, 190]}, {'name': 'car', 'percentage_probability': 68.79, 'box_points': [230, 56, 267, 92]}, {'name': 'car', 'percentage_probability': 65.33, 'box_points': [121, 57, 194, 100]}, {'name': 'person', 'percentage_probability': 55.68, 'box_points': [197, 73, 216, 123]}, {'name': 'car', 'percentage_probability': 51.49, 'box_points': [273, 65, 303, 106]}]]
# Array for output count for unique objects in each frame :  [{'motorcycle': 2, 'car': 3, 'person': 1}]
# Output average count for unique objects in the last second:  {'motorcycle': 2, 'car': 3, 'person': 1}
# ------------END OF A SECOND --------------
# SECOND :  43
# Array for the outputs of each frame  [[{'name': 'person', 'percentage_probability': 94.83, 'box_points': [168, 102, 200, 159]}, {'name': 'motorcycle', 'percentage_probability': 74.93, 'box_points': [113, 86, 164, 128]}, {'name': 'car', 'percentage_probability': 70.39, 'box_points': [230, 56, 267, 92]}, {'name': 'motorcycle', 'percentage_probability': 68.76, 'box_points': [0, 126, 63, 191]}, {'name': 'motorcycle', 'percentage_probability': 64.48, 'box_points': [183, 70, 217, 104]}, {'name': 'car', 'percentage_probability': 54.84, 'box_points': [123, 54, 210, 98]}]]
# Array for output count for unique objects in each frame :  [{'person': 1, 'motorcycle': 3, 'car': 2}]
# Output average count for unique objects in the last second:  {'person': 1, 'motorcycle': 3, 'car': 2}
# ------------END OF A SECOND --------------
# SECOND :  44
# Array for the outputs of each frame  [[{'name': 'person', 'percentage_probability': 96.98, 'box_points': [143, 126, 175, 199]}, {'name': 'motorcycle', 'percentage_probability': 78.89, 'box_points': [5, 126, 59, 186]}, {'name': 'motorcycle', 'percentage_probability': 77.15, 'box_points': [113, 86, 166, 127]}, {'name': 'motorcycle', 'percentage_probability': 72.04, 'box_points': [187, 70, 223, 103]}, {'name': 'car', 'percentage_probability': 62.78, 'box_points': [231, 55, 267, 92]}, {'name': 'car', 'percentage_probability': 62.11, 'box_points': [121, 52, 210, 99]}]]
# Array for output count for unique objects in each frame :  [{'person': 1, 'motorcycle': 3, 'car': 2}]
# Output average count for unique objects in the last second:  {'person': 1, 'motorcycle': 3, 'car': 2}
# ------------END OF A SECOND --------------
# SECOND :  45
# Array for the outputs of each frame  [[{'name': 'car', 'percentage_probability': 81.64, 'box_points': [121, 52, 208, 99]}, {'name': 'motorcycle', 'percentage_probability': 77.29, 'box_points': [113, 87, 164, 128]}, {'name': 'motorcycle', 'percentage_probability': 67.64, 'box_points': [204, 73, 246, 106]}, {'name': 'motorcycle', 'percentage_probability': 66.82, 'box_points': [0, 126, 74, 208]}]]
# Array for output count for unique objects in each frame :  [{'car': 1, 'motorcycle': 3}]
# Output average count for unique objects in the last second:  {'car': 1, 'motorcycle': 3}
# ------------END OF A SECOND --------------
# SECOND :  46
# Array for the outputs of each frame  [[{'name': 'motorcycle', 'percentage_probability': 82.81, 'box_points': [213, 78, 253, 109]}, {'name': 'car', 'percentage_probability': 82.16, 'box_points': [121, 52, 208, 99]}, {'name': 'motorcycle', 'percentage_probability': 77.87, 'box_points': [113, 87, 164, 128]}, {'name': 'motorcycle', 'percentage_probability': 74.79, 'box_points': [6, 130, 57, 186]}]]
# Array for output count for unique objects in each frame :  [{'motorcycle': 3, 'car': 1}]
# Output average count for unique objects in the last second:  {'motorcycle': 3, 'car': 1}
# ------------END OF A SECOND --------------
# SECOND :  47
# Array for the outputs of each frame  [[{'name': 'car', 'percentage_probability': 79.25, 'box_points': [121, 52, 207, 99]}, {'name': 'motorcycle', 'percentage_probability': 77.76, 'box_points': [113, 86, 164, 128]}, {'name': 'motorcycle', 'percentage_probability': 62.73, 'box_points': [218, 56, 266, 110]}, {'name': 'motorcycle', 'percentage_probability': 54.05, 'box_points': [2, 126, 63, 185]}]]
# Array for output count for unique objects in each frame :  [{'car': 1, 'motorcycle': 3}]
# Output average count for unique objects in the last second:  {'car': 1, 'motorcycle': 3}
# ------------END OF A SECOND --------------
# SECOND :  48
# Array for the outputs of each frame  [[{'name': 'car', 'percentage_probability': 81.81, 'box_points': [121, 52, 207, 99]}, {'name': 'motorcycle', 'percentage_probability': 70.94, 'box_points': [112, 87, 165, 127]}, {'name': 'car', 'percentage_probability': 61.2, 'box_points': [275, 67, 304, 111]}, {'name': 'car', 'percentage_probability': 50.87, 'box_points': [23, 121, 205, 209]}, {'name': 'motorcycle', 'percentage_probability': 50.83, 'box_points': [9, 132, 53, 185]}]]
# Array for output count for unique objects in each frame :  [{'car': 3, 'motorcycle': 2}]
# Output average count for unique objects in the last second:  {'car': 3, 'motorcycle': 2}
# ------------END OF A SECOND --------------
# SECOND :  49
# Array for the outputs of each frame  [[{'name': 'person', 'percentage_probability': 96.57, 'box_points': [59, 115, 100, 195]}, {'name': 'motorcycle', 'percentage_probability': 75.2, 'box_points': [3, 134, 54, 187]}, {'name': 'car', 'percentage_probability': 66.85, 'box_points': [146, 77, 228, 151]}, {'name': 'motorcycle', 'percentage_probability': 64.98, 'box_points': [111, 86, 156, 127]}, {'name': 'car', 'percentage_probability': 62.65, 'box_points': [121, 54, 208, 99]}]]
# Array for output count for unique objects in each frame :  [{'person': 1, 'motorcycle': 2, 'car': 2}]
# Output average count for unique objects in the last second:  {'person': 1, 'motorcycle': 2, 'car': 2}
# ------------END OF A SECOND --------------
# SECOND :  50
# Array for the outputs of each frame  [[{'name': 'person', 'percentage_probability': 78.03, 'box_points': [105, 101, 135, 167]}, {'name': 'motorcycle', 'percentage_probability': 76.6, 'box_points': [2, 129, 60, 187]}, {'name': 'motorcycle', 'percentage_probability': 61.94, 'box_points': [129, 93, 165, 127]}, {'name': 'car', 'percentage_probability': 51.6, 'box_points': [177, 63, 239, 124]}, {'name': 'car', 'percentage_probability': 50.62, 'box_points': [136, 60, 199, 98]}]]
# Array for output count for unique objects in each frame :  [{'person': 1, 'motorcycle': 2, 'car': 2}]
# Output average count for unique objects in the last second:  {'person': 1, 'motorcycle': 2, 'car': 2}
# ------------END OF A SECOND --------------
# SECOND :  51
# Array for the outputs of each frame  [[{'name': 'motorcycle', 'percentage_probability': 85.47, 'box_points': [113, 89, 163, 128]}, {'name': 'car', 'percentage_probability': 80.58, 'box_points': [152, 52, 221, 94]}, {'name': 'car', 'percentage_probability': 76.88, 'box_points': [204, 65, 252, 120]}, {'name': 'person', 'percentage_probability': 73.65, 'box_points': [36, 113, 76, 183]}, {'name': 'person', 'percentage_probability': 73.6, 'box_points': [168, 88, 210, 181]}, {'name': 'motorcycle', 'percentage_probability': 70.16, 'box_points': [7, 134, 52, 188]}]]
# Array for output count for unique objects in each frame :  [{'motorcycle': 2, 'car': 2, 'person': 2}]
# Output average count for unique objects in the last second:  {'motorcycle': 2, 'car': 2, 'person': 2}
# ------------END OF A SECOND --------------
# SECOND :  52
# Array for the outputs of each frame  [[{'name': 'motorcycle', 'percentage_probability': 88.75, 'box_points': [115, 88, 165, 128]}, {'name': 'person', 'percentage_probability': 87.19, 'box_points': [193, 98, 230, 148]}, {'name': 'car', 'percentage_probability': 81.02, 'box_points': [152, 53, 215, 96]}, {'name': 'person', 'percentage_probability': 76.17, 'box_points': [182, 78, 198, 122]}, {'name': 'motorcycle', 'percentage_probability': 75.46, 'box_points': [9, 125, 57, 187]}, {'name': 'car', 'percentage_probability': 63.56, 'box_points': [207, 64, 253, 122]}, {'name': 'dog', 'percentage_probability': 57.38, 'box_points': [60, 101, 99, 168]}, {'name': 'person', 'percentage_probability': 57.07, 'box_points': [184, 64, 214, 122]}]]
# Array for output count for unique objects in each frame :  [{'motorcycle': 2, 'person': 3, 'car': 2, 'dog': 1}]
# Output average count for unique objects in the last second:  {'motorcycle': 2, 'person': 3, 'car': 2, 'dog': 1}
# ------------END OF A SECOND --------------
# SECOND :  53
# Array for the outputs of each frame  [[{'name': 'person', 'percentage_probability': 96.6, 'box_points': [64, 129, 107, 204]}, {'name': 'car', 'percentage_probability': 80.18, 'box_points': [151, 52, 215, 97]}, {'name': 'motorcycle', 'percentage_probability': 79.13, 'box_points': [124, 89, 165, 127]}, {'name': 'person', 'percentage_probability': 77.49, 'box_points': [240, 87, 259, 138]}, {'name': 'motorcycle', 'percentage_probability': 76.24, 'box_points': [1, 125, 58, 187]}, {'name': 'person', 'percentage_probability': 75.11, 'box_points': [90, 88, 128, 141]}, {'name': 'car', 'percentage_probability': 65.69, 'box_points': [202, 58, 270, 119]}, {'name': 'backpack', 'percentage_probability': 51.38, 'box_points': [92, 97, 110, 121]}]]
# Array for output count for unique objects in each frame :  [{'person': 3, 'car': 2, 'motorcycle': 2, 'backpack': 1}]
# Output average count for unique objects in the last second:  {'person': 3, 'car': 2, 'motorcycle': 2, 'backpack': 1}
# ------------END OF A SECOND --------------
# SECOND :  54
# Array for the outputs of each frame  [[{'name': 'car', 'percentage_probability': 86.42, 'box_points': [151, 52, 216, 96]}, {'name': 'motorcycle', 'percentage_probability': 80.45, 'box_points': [127, 90, 165, 128]}, {'name': 'car', 'percentage_probability': 78.81, 'box_points': [201, 60, 268, 120]}, {'name': 'person', 'percentage_probability': 78.67, 'box_points': [89, 88, 130, 173]}, {'name': 'motorcycle', 'percentage_probability': 74.5, 'box_points': [1, 121, 61, 194]}]]
# Array for output count for unique objects in each frame :  [{'car': 2, 'motorcycle': 2, 'person': 1}]
# Output average count for unique objects in the last second:  {'car': 2, 'motorcycle': 2, 'person': 1}
# ------------END OF A SECOND --------------
# SECOND :  55
# Array for the outputs of each frame  [[{'name': 'car', 'percentage_probability': 86.76, 'box_points': [151, 51, 218, 96]}, {'name': 'person', 'percentage_probability': 86.47, 'box_points': [95, 76, 122, 134]}, {'name': 'car', 'percentage_probability': 78.85, 'box_points': [203, 66, 261, 120]}, {'name': 'motorcycle', 'percentage_probability': 76.21, 'box_points': [122, 91, 153, 126]}, {'name': 'motorcycle', 'percentage_probability': 75.2, 'box_points': [0, 126, 61, 193]}, {'name': 'person', 'percentage_probability': 67.36, 'box_points': [157, 90, 178, 145]}, {'name': 'motorcycle', 'percentage_probability': 61.66, 'box_points': [134, 90, 160, 125]}, {'name': 'person', 'percentage_probability': 54.17, 'box_points': [155, 120, 186, 200]}]]
# Array for output count for unique objects in each frame :  [{'car': 2, 'person': 3, 'motorcycle': 3}]
# Output average count for unique objects in the last second:  {'car': 2, 'person': 3, 'motorcycle': 3}
# ------------END OF A SECOND --------------
# SECOND :  56
# Array for the outputs of each frame  [[{'name': 'person', 'percentage_probability': 86.15, 'box_points': [95, 79, 129, 135]}, {'name': 'motorcycle', 'percentage_probability': 76.0, 'box_points': [0, 125, 61, 190]}, {'name': 'motorcycle', 'percentage_probability': 74.82, 'box_points': [125, 93, 163, 125]}, {'name': 'car', 'percentage_probability': 71.96, 'box_points': [200, 70, 252, 128]}, {'name': 'car', 'percentage_probability': 71.18, 'box_points': [152, 51, 217, 96]}, {'name': 'person', 'percentage_probability': 51.08, 'box_points': [170, 91, 192, 130]}, {'name': 'person', 'percentage_probability': 50.37, 'box_points': [182, 119, 208, 173]}]]
# Array for output count for unique objects in each frame :  [{'person': 3, 'motorcycle': 2, 'car': 2}]
# Output average count for unique objects in the last second:  {'person': 3, 'motorcycle': 2, 'car': 2}
# ------------END OF A SECOND --------------
# SECOND :  57
# Array for the outputs of each frame  [[{'name': 'person', 'percentage_probability': 88.5, 'box_points': [89, 74, 121, 132]}, {'name': 'motorcycle', 'percentage_probability': 78.2, 'box_points': [3, 131, 55, 187]}, {'name': 'motorcycle', 'percentage_probability': 75.59, 'box_points': [116, 90, 152, 127]}, {'name': 'car', 'percentage_probability': 73.64, 'box_points': [191, 80, 253, 155]}, {'name': 'person', 'percentage_probability': 69.32, 'box_points': [162, 71, 206, 145]}, {'name': 'car', 'percentage_probability': 60.34, 'box_points': [152, 52, 218, 91]}, {'name': 'motorcycle', 'percentage_probability': 58.88, 'box_points': [129, 90, 160, 124]}]]
# Array for output count for unique objects in each frame :  [{'person': 2, 'motorcycle': 3, 'car': 2}]
# Output average count for unique objects in the last second:  {'person': 2, 'motorcycle': 3, 'car': 2}
# ------------END OF A SECOND --------------
# SECOND :  58
# Array for the outputs of each frame  [[{'name': 'car', 'percentage_probability': 81.67, 'box_points': [191, 82, 254, 155]}, {'name': 'motorcycle', 'percentage_probability': 78.7, 'box_points': [3, 128, 57, 187]}, {'name': 'person', 'percentage_probability': 73.98, 'box_points': [148, 88, 175, 136]}, {'name': 'motorcycle', 'percentage_probability': 70.95, 'box_points': [116, 89, 152, 127]}, {'name': 'person', 'percentage_probability': 63.87, 'box_points': [86, 70, 116, 116]}, {'name': 'car', 'percentage_probability': 56.06, 'box_points': [166, 53, 221, 84]}]]
# Array for output count for unique objects in each frame :  [{'car': 2, 'motorcycle': 2, 'person': 2}]
# Output average count for unique objects in the last second:  {'car': 2, 'motorcycle': 2, 'person': 2}
# ------------END OF A SECOND --------------
# SECOND :  59
# Array for the outputs of each frame  [[{'name': 'motorcycle', 'percentage_probability': 79.41, 'box_points': [10, 125, 59, 187]}, {'name': 'car', 'percentage_probability': 72.6, 'box_points': [161, 52, 221, 87]}, {'name': 'car', 'percentage_probability': 72.52, 'box_points': [191, 83, 256, 156]}, {'name': 'person', 'percentage_probability': 69.79, 'box_points': [97, 69, 128, 113]}, {'name': 'person', 'percentage_probability': 68.76, 'box_points': [138, 70, 170, 137]}, {'name': 'motorcycle', 'percentage_probability': 61.14, 'box_points': [115, 89, 150, 133]}]]
# Array for output count for unique objects in each frame :  [{'motorcycle': 2, 'car': 2, 'person': 2}]
# Output average count for unique objects in the last second:  {'motorcycle': 2, 'car': 2, 'person': 2}
# ------------END OF A SECOND --------------
# SECOND :  60
# Array for the outputs of each frame  [[{'name': 'person', 'percentage_probability': 80.47, 'box_points': [90, 69, 124, 116]}, {'name': 'motorcycle', 'percentage_probability': 78.05, 'box_points': [6, 126, 58, 187]}, {'name': 'car', 'percentage_probability': 77.75, 'box_points': [192, 84, 257, 154]}, {'name': 'car', 'percentage_probability': 74.98, 'box_points': [168, 52, 221, 86]}, {'name': 'person', 'percentage_probability': 72.33, 'box_points': [160, 82, 179, 128]}, {'name': 'motorcycle', 'percentage_probability': 68.4, 'box_points': [121, 87, 157, 127]}]]
# Array for output count for unique objects in each frame :  [{'person': 2, 'motorcycle': 2, 'car': 2}]
# Output average count for unique objects in the last second:  {'person': 2, 'motorcycle': 2, 'car': 2}
# ------------END OF A SECOND --------------
# MINUTE :  1
# Array for the outputs of each frame  [[{'name': 'car', 'percentage_probability': 87.97, 'box_points': [122, 53, 206, 101]}, {'name': 'person', 'percentage_probability': 84.26, 'box_points': [215, 52, 225, 78]}], [{'name': 'car', 'percentage_probability': 90.7, 'box_points': [122, 53, 206, 100]}, {'name': 'person', 'percentage_probability': 78.88, 'box_points': [217, 52, 226, 76]}], [{'name': 'car', 'percentage_probability': 90.76, 'box_points': [122, 53, 207, 100]}, {'name': 'person', 'percentage_probability': 76.79, 'box_points': [216, 51, 226, 76]}], [{'name': 'car', 'percentage_probability': 89.42, 'box_points': [122, 54, 207, 101]}, {'name': 'person', 'percentage_probability': 68.88, 'box_points': [220, 50, 229, 74]}], [{'name': 'car', 'percentage_probability': 89.04, 'box_points': [121, 54, 206, 101]}, {'name': 'person', 'percentage_probability': 80.92, 'box_points': [221, 50, 231, 73]}], [{'name': 'car', 'percentage_probability': 88.64, 'box_points': [121, 54, 207, 101]}, {'name': 'person', 'percentage_probability': 84.87, 'box_points': [223, 49, 233, 72]}], [{'name': 'car', 'percentage_probability': 87.06, 'box_points': [121, 54, 207, 101]}, {'name': 'person', 'percentage_probability': 79.73, 'box_points': [225, 50, 233, 72]}, {'name': 'car', 'percentage_probability': 57.61, 'box_points': [260, 46, 272, 65]}], [{'name': 'car', 'percentage_probability': 88.61, 'box_points': [121, 55, 207, 101]}, {'name': 'person', 'percentage_probability': 61.16, 'box_points': [225, 49, 233, 71]}, {'name': 'car', 'percentage_probability': 53.53, 'box_points': [260, 45, 272, 65]}], [{'name': 'car', 'percentage_probability': 89.02, 'box_points': [122, 54, 207, 100]}, {'name': 'person', 'percentage_probability': 69.74, 'box_points': [225, 49, 233, 71]}, {'name': 'car', 'percentage_probability': 62.96, 'box_points': [259, 46, 272, 67]}], [{'name': 'car', 'percentage_probability': 90.94, 'box_points': [121, 53, 207, 101]}, {'name': 'person', 'percentage_probability': 75.87, 'box_points': [225, 49, 233, 71]}, {'name': 'car', 'percentage_probability': 67.0, 'box_points': [257, 46, 272, 67]}], [{'name': 'car', 'percentage_probability': 90.87, 'box_points': [121, 54, 207, 101]}, {'name': 'person', 'percentage_probability': 79.89, 'box_points': [226, 49, 233, 70]}, {'name': 'car', 'percentage_probability': 72.96, 'box_points': [256, 45, 272, 69]}], [{'name': 'car', 'percentage_probability': 90.5, 'box_points': [121, 54, 207, 101]}, {'name': 'person', 'percentage_probability': 76.73, 'box_points': [225, 46, 236, 71]}, {'name': 'car', 'percentage_probability': 57.37, 'box_points': [254, 47, 272, 71]}], [{'name': 'car', 'percentage_probability': 91.03, 'box_points': [121, 53, 207, 101]}, {'name': 'person', 'percentage_probability': 82.45, 'box_points': [226, 47, 236, 70]}, {'name': 'car', 'percentage_probability': 66.96, 'box_points': [251, 44, 276, 75]}], [{'name': 'car', 'percentage_probability': 89.75, 'box_points': [121, 54, 207, 101]}, {'name': 'person', 'percentage_probability': 82.17, 'box_points': [227, 46, 238, 70]}, {'name': 'car', 'percentage_probability': 64.88, 'box_points': [248, 48, 284, 77]}, {'name': 'person', 'percentage_probability': 52.54, 'box_points': [240, 45, 250, 61]}], [{'name': 'car', 'percentage_probability': 88.55, 'box_points': [121, 54, 207, 101]}, {'name': 'person', 'percentage_probability': 75.97, 'box_points': [230, 46, 238, 68]}, {'name': 'car', 'percentage_probability': 62.48, 'box_points': [243, 45, 293, 85]}], [{'name': 'car', 'percentage_probability': 88.23, 'box_points': [121, 54, 207, 101]}, {'name': 'person', 'percentage_probability': 77.97, 'box_points': [231, 47, 240, 68]}, {'name': 'car', 'percentage_probability': 63.08, 'box_points': [240, 44, 298, 94]}], [{'name': 'car', 'percentage_probability': 89.21, 'box_points': [121, 54, 207, 101]}, {'name': 'car', 'percentage_probability': 57.42, 'box_points': [235, 46, 270, 87]}, {'name': 'car', 'percentage_probability': 54.1, 'box_points': [274, 64, 299, 101]},  ...
# Array for output count for unique objects in each frame :  [{'car': 1, 'person': 1}, {'car': 1, 'person': 1}, {'car': 1, 'person': 1}, {'car': 1, 'person': 1}, {'car': 1, 'person': 1}, {'car': 1, 'person': 1}, {'car': 2, 'person': 1}, {'car': 2, 'person': 1}, {'car': 2, 'person': 1}, {'car': 2, 'person': 1}, {'car': 2, 'person': 1}, {'car': 2, 'person': 1}, {'car': 2, 'person': 1}, {'car': 2, 'person': 2}, {'car': 2, 'person': 1}, {'car': 2, 'person': 1}, {'car': 3, 'person': 1}, {'car': 3, 'mouse': 1}, {'car': 3, 'cell phone': 1, 'mouse': 1}, {'car': 4}, {'car': 2}, {'car': 2}, {'car': 2}, {'car': 2, 'motorcycle': 1, 'person': 1}, {'motorcycle': 1, 'car': 2}, {'car': 2, 'motorcycle': 1}, {'car': 4, 'motorcycle': 1}, {'car': 2, 'motorcycle': 1, 'person': 1}, {'car': 1, 'motorcycle': 2}, {'car': 1, 'motorcycle': 2}, {'car': 1, 'motorcycle': 1, 'cell phone': 1}, {'person': 1, 'car': 2, 'motorcycle': 1}, {'person': 2, 'motorcycle': 2, 'car': 3}, {'motorcycle': 3, 'car': 2, 'person': 2}, {'person': 2, 'motorcycle': 4, 'car': 2}, {'person': 2, 'motorcycle': 3, 'car': 2}, {'motorcycle': 3, 'person': 2, 'car': 3}, {'person': 3, 'motorcycle': 3, 'car': 4}, {'person': 2, 'motorcycle': 3, 'car': 3}, {'person': 1, 'motorcycle': 3, 'car': 2}, {'motorcycle': 3, 'car': 3}, {'motorcycle': 2, 'car': 3, 'person': 1}, {'person': 1, 'motorcycle': 3, 'car': 2}, {'person': 1, 'motorcycle': 3, 'car': 2}, {'car': 1, 'motorcycle': 3}, {'motorcycle': 3, 'car': 1}, {'car': 1, 'motorcycle': 3}, {'car': 3, 'motorcycle': 2}, {'person': 1, 'motorcycle': 2, 'car': 2}, {'person': 1, 'motorcycle': 2, 'car': 2}, {'motorcycle': 2, 'car': 2, 'person': 2}, {'motorcycle': 2, 'person': 3, 'car': 2, 'dog': 1}, {'person': 3, 'car': 2, 'motorcycle': 2, 'backpack': 1}, {'car': 2, 'motorcycle': 2, 'person': 1}, {'car': 2, 'person': 3, 'motorcycle': 3}, {'person': 3, 'motorcycle': 2, 'car': 2}, {'person': 2, 'motorcycle': 3, 'car': 2}, {'car': 2, 'motorcycle': 2, 'person': 2}, {'motorcycle': 2, 'car': 2, 'person': 2}, {'person': 2, 'motorcycle': 2, 'car': 2}]
# Output average count for unique objects in the last minute:  {'car': 2, 'person': 1, 'mouse': 0, 'cell phone': 0, 'motorcycle': 1, 'dog': 0, 'backpack': 0}
# ------------END OF A MINUTE --------------
# SECOND :  61
# Array for the outputs of each frame  [[{'name': 'person', 'percentage_probability': 90.29, 'box_points': [100, 84, 133, 140]}, {'name': 'car', 'percentage_probability': 76.92, 'box_points': [192, 83, 253, 155]}, {'name': 'motorcycle', 'percentage_probability': 74.26, 'box_points': [127, 96, 157, 126]}, {'name': 'car', 'percentage_probability': 65.15, 'box_points': [158, 53, 222, 93]}, {'name': 'motorcycle', 'percentage_probability': 63.13, 'box_points': [3, 114, 62, 207]}, {'name': 'person', 'percentage_probability': 52.18, 'box_points': [136, 76, 160, 111]}]]
# Array for output count for unique objects in each frame :  [{'person': 2, 'car': 2, 'motorcycle': 2}]
# Output average count for unique objects in the last second:  {'person': 2, 'car': 2, 'motorcycle': 2}
# ------------END OF A SECOND --------------
# SECOND :  62
# ...
# Array for output count for unique objects in each frame :  [{'person': 2, 'motorcycle': 2, 'car': 1}]
# Output average count for unique objects in the last second:  {'person': 2, 'motorcycle': 2, 'car': 1}
# ------------END OF A SECOND --------------
# SECOND :  195
# Array for the outputs of each frame  [[{'name': 'person', 'percentage_probability': 90.88, 'box_points': [56, 107, 85, 182]}, {'name': 'motorcycle', 'percentage_probability': 81.96, 'box_points': [117, 89, 166, 128]}, {'name': 'motorcycle', 'percentage_probability': 74.82, 'box_points': [6, 129, 52, 187]}, {'name': 'car', 'percentage_probability': 71.28, 'box_points': [201, 63, 261, 111]}, {'name': 'person', 'percentage_probability': 55.99, 'box_points': [167, 63, 185, 113]}]]
# Array for output count for unique objects in each frame :  [{'person': 2, 'motorcycle': 2, 'car': 1}]
# Output average count for unique objects in the last second:  {'person': 2, 'motorcycle': 2, 'car': 1}
# ------------END OF A SECOND --------------
# SECOND :  196
# Array for the outputs of each frame  [[{'name': 'person', 'percentage_probability': 87.64, 'box_points': [54, 106, 85, 182]}, {'name': 'motorcycle', 'percentage_probability': 85.55, 'box_points': [119, 86, 167, 128]}, {'name': 'motorcycle', 'percentage_probability': 72.06, 'box_points': [12, 128, 52, 186]}, {'name': 'car', 'percentage_probability': 67.14, 'box_points': [201, 64, 262, 111]}, {'name': 'person', 'percentage_probability': 66.99, 'box_points': [167, 56, 192, 114]}]]
# Array for output count for unique objects in each frame :  [{'person': 2, 'motorcycle': 2, 'car': 1}]
# Output average count for unique objects in the last second:  {'person': 2, 'motorcycle': 2, 'car': 1}
# ------------END OF A SECOND --------------
# SECOND :  197
# Array for the outputs of each frame  [[{'name': 'person', 'percentage_probability': 91.0, 'box_points': [54, 110, 85, 182]}, {'name': 'motorcycle', 'percentage_probability': 89.53, 'box_points': [119, 86, 166, 128]}, {'name': 'person', 'percentage_probability': 81.31, 'box_points': [165, 55, 195, 115]}, {'name': 'car', 'percentage_probability': 75.46, 'box_points': [202, 64, 262, 111]}, {'name': 'motorcycle', 'percentage_probability': 72.52, 'box_points': [2, 125, 53, 191]}, {'name': 'person', 'percentage_probability': 72.09, 'box_points': [107, 68, 128, 111]}, {'name': 'person', 'percentage_probability': 67.33, 'box_points': [18, 53, 30, 85]}]]
# Array for output count for unique objects in each frame :  [{'person': 4, 'motorcycle': 2, 'car': 1}]
# Output average count for unique objects in the last second:  {'person': 4, 'motorcycle': 2, 'car': 1}
# ------------END OF A SECOND --------------
# SECOND :  198
# Array for the outputs of each frame  [[{'name': 'person', 'percentage_probability': 91.0, 'box_points': [56, 110, 85, 183]}, {'name': 'person', 'percentage_probability': 74.92, 'box_points': [168, 68, 191, 120]}, {'name': 'car', 'percentage_probability': 74.59, 'box_points': [202, 66, 262, 111]}, {'name': 'motorcycle', 'percentage_probability': 74.4, 'box_points': [116, 84, 166, 127]}, {'name': 'motorcycle', 'percentage_probability': 68.58, 'box_points': [3, 129, 52, 189]}, {'name': 'person', 'percentage_probability': 54.22, 'box_points': [17, 53, 29, 85]}]]
# Array for output count for unique objects in each frame :  [{'person': 3, 'car': 1, 'motorcycle': 2}]
# Output average count for unique objects in the last second:  {'person': 3, 'car': 1, 'motorcycle': 2}
# ------------END OF A SECOND --------------
# SECOND :  199
# Array for the outputs of each frame  [[{'name': 'person', 'percentage_probability': 92.77, 'box_points': [53, 114, 83, 195]}, {'name': 'motorcycle', 'percentage_probability': 79.15, 'box_points': [115, 80, 167, 128]}, {'name': 'motorcycle', 'percentage_probability': 65.45, 'box_points': [4, 135, 50, 188]}, {'name': 'person', 'percentage_probability': 59.37, 'box_points': [169, 58, 203, 120]}, {'name': 'person', 'percentage_probability': 57.59, 'box_points': [173, 74, 196, 120]}, {'name': 'motorcycle', 'percentage_probability': 56.65, 'box_points': [121, 92, 155, 127]}, {'name': 'car', 'percentage_probability': 55.22, 'box_points': [200, 63, 262, 113]}, {'name': 'car', 'percentage_probability': 52.9, 'box_points': [167, 55, 211, 83]}]]
# Array for output count for unique objects in each frame :  [{'person': 3, 'motorcycle': 3, 'car': 2}]
# Output average count for unique objects in the last second:  {'person': 3, 'motorcycle': 3, 'car': 2}
# ------------END OF A SECOND --------------
# SECOND :  200
# Array for the outputs of each frame  [[{'name': 'motorcycle', 'percentage_probability': 80.84, 'box_points': [117, 91, 167, 128]}, {'name': 'person', 'percentage_probability': 71.96, 'box_points': [170, 73, 193, 121]}, {'name': 'person', 'percentage_probability': 57.93, 'box_points': [133, 78, 158, 116]}, {'name': 'motorcycle', 'percentage_probability': 53.83, 'box_points': [1, 135, 60, 202]}, {'name': 'person', 'percentage_probability': 52.18, 'box_points': [31, 129, 72, 203]}, {'name': 'car', 'percentage_probability': 51.6, 'box_points': [201, 62, 264, 107]}, {'name': 'truck', 'percentage_probability': 50.13, 'box_points': [202, 47, 271, 110]}]]
# Array for output count for unique objects in each frame :  [{'motorcycle': 2, 'person': 3, 'car': 1, 'truck': 1}]
# Output average count for unique objects in the last second:  {'motorcycle': 2, 'person': 3, 'car': 1, 'truck': 1}
# ------------END OF A SECOND --------------
# SECOND :  201
# Array for the outputs of each frame  [[{'name': 'person', 'percentage_probability': 87.03, 'box_points': [157, 68, 201, 149]}, {'name': 'motorcycle', 'percentage_probability': 82.3, 'box_points': [124, 98, 157, 127]}, {'name': 'car', 'percentage_probability': 72.53, 'box_points': [203, 64, 261, 111]}, {'name': 'person', 'percentage_probability': 67.83, 'box_points': [8, 56, 20, 87]}, {'name': 'motorcycle', 'percentage_probability': 63.73, 'box_points': [18, 127, 61, 186]}, {'name': 'motorcycle', 'percentage_probability': 54.13, 'box_points': [113, 83, 162, 127]}]]
# Array for output count for unique objects in each frame :  [{'person': 2, 'motorcycle': 3, 'car': 1}]
# Output average count for unique objects in the last second:  {'person': 2, 'motorcycle': 3, 'car': 1}
# ------------END OF A SECOND --------------
# SECOND :  202
# Array for the outputs of each frame  [[{'name': 'person', 'percentage_probability': 86.51, 'box_points': [135, 93, 169, 166]}, {'name': 'motorcycle', 'percentage_probability': 69.59, 'box_points': [10, 128, 59, 188]}, {'name': 'person', 'percentage_probability': 66.05, 'box_points': [113, 83, 164, 158]}, {'name': 'car', 'percentage_probability': 65.55, 'box_points': [202, 63, 262, 110]}, {'name': 'person', 'percentage_probability': 56.9, 'box_points': [168, 60, 186, 108]}]]
# Array for output count for unique objects in each frame :  [{'person': 3, 'motorcycle': 1, 'car': 1}]
# Output average count for unique objects in the last second:  {'person': 3, 'motorcycle': 1, 'car': 1}
# ------------END OF A SECOND --------------
# SECOND :  203
# Array for the outputs of each frame  [[{'name': 'person', 'percentage_probability': 83.99, 'box_points': [113, 80, 162, 170]}, {'name': 'motorcycle', 'percentage_probability': 74.72, 'box_points': [12, 123, 62, 189]}, {'name': 'car', 'percentage_probability': 73.63, 'box_points': [202, 63, 261, 111]}, {'name': 'person', 'percentage_probability': 67.02, 'box_points': [168, 51, 188, 103]}, {'name': 'person', 'percentage_probability': 52.23, 'box_points': [1, 57, 11, 88]}]]
# Array for output count for unique objects in each frame :  [{'person': 3, 'motorcycle': 1, 'car': 1}]
# Output average count for unique objects in the last second:  {'person': 3, 'motorcycle': 1, 'car': 1}
# ------------END OF A SECOND --------------
# SECOND :  204
# Array for the outputs of each frame  [[{'name': 'person', 'percentage_probability': 93.63, 'box_points': [122, 91, 164, 167]}, {'name': 'car', 'percentage_probability': 77.99, 'box_points': [202, 63, 260, 111]}, {'name': 'motorcycle', 'percentage_probability': 74.97, 'box_points': [9, 124, 63, 190]}, {'name': 'person', 'percentage_probability': 62.83, 'box_points': [168, 58, 189, 102]}, {'name': 'person', 'percentage_probability': 56.0, 'box_points': [116, 78, 154, 148]}]]
# Array for output count for unique objects in each frame :  [{'person': 3, 'car': 1, 'motorcycle': 1}]
# Output average count for unique objects in the last second:  {'person': 3, 'car': 1, 'motorcycle': 1}
# ------------END OF A SECOND --------------
# SECOND :  205
# Array for the outputs of each frame  [[{'name': 'motorcycle', 'percentage_probability': 79.11, 'box_points': [0, 117, 63, 208]}, {'name': 'person', 'percentage_probability': 75.06, 'box_points': [116, 81, 153, 154]}, {'name': 'car', 'percentage_probability': 67.05, 'box_points': [200, 63, 262, 110]}, {'name': 'skis', 'percentage_probability': 51.41, 'box_points': [125, 149, 146, 158]}]]
# Array for output count for unique objects in each frame :  [{'motorcycle': 1, 'person': 1, 'car': 1, 'skis': 1}]
# Output average count for unique objects in the last second:  {'motorcycle': 1, 'person': 1, 'car': 1, 'skis': 1}
# ------------END OF A SECOND --------------
# SECOND :  206
# Array for the outputs of each frame  [[]]
# Array for output count for unique objects in each frame :  [{}]
# Output average count for unique objects in the last second:  {}
# ------------END OF A SECOND --------------
# SECOND :  207
# Array for the outputs of each frame  [[{'name': 'motorcycle', 'percentage_probability': 68.38, 'box_points': [119, 92, 154, 130]}, {'name': 'car', 'percentage_probability': 60.18, 'box_points': [201, 62, 262, 111]}, {'name': 'person', 'percentage_probability': 53.55, 'box_points': [146, 63, 174, 131]}]]
# Array for output count for unique objects in each frame :  [{'motorcycle': 1, 'car': 1, 'person': 1}]
# Output average count for unique objects in the last second:  {'motorcycle': 1, 'car': 1, 'person': 1}
# ------------END OF A SECOND --------------
# SECOND :  208
# Array for the outputs of each frame  [[{'name': 'motorcycle', 'percentage_probability': 79.0, 'box_points': [120, 91, 154, 127]}, {'name': 'car', 'percentage_probability': 60.34, 'box_points': [200, 64, 263, 111]}]]
# Array for output count for unique objects in each frame :  [{'motorcycle': 1, 'car': 1}]
# Output average count for unique objects in the last second:  {'motorcycle': 1, 'car': 1}
# ------------END OF A SECOND --------------
# SECOND :  209
# Array for the outputs of each frame  [[{'name': 'car', 'percentage_probability': 63.4, 'box_points': [195, 62, 263, 111]}, {'name': 'person', 'percentage_probability': 61.39, 'box_points': [22, 122, 64, 207]}, {'name': 'car', 'percentage_probability': 56.16, 'box_points': [170, 53, 231, 84]}, {'name': 'person', 'percentage_probability': 52.85, 'box_points': [116, 59, 129, 97]}]]
# Array for output count for unique objects in each frame :  [{'car': 2, 'person': 2}]
# Output average count for unique objects in the last second:  {'car': 2, 'person': 2}
# ------------END OF A SECOND --------------
# SECOND :  210
# Array for the outputs of each frame  [[{'name': 'person', 'percentage_probability': 84.49, 'box_points': [97, 60, 135, 139]}, {'name': 'motorcycle', 'percentage_probability': 77.58, 'box_points': [127, 89, 166, 128]}, {'name': 'motorcycle', 'percentage_probability': 77.11, 'box_points': [3, 125, 70, 201]}, {'name': 'person', 'percentage_probability': 75.93, 'box_points': [10, 81, 35, 144]}, {'name': 'car', 'percentage_probability': 63.22, 'box_points': [196, 60, 263, 110]}, {'name': 'snowboard', 'percentage_probability': 56.82, 'box_points': [105, 125, 134, 142]}]]
# Array for output count for unique objects in each frame :  [{'person': 2, 'motorcycle': 2, 'car': 1, 'snowboard': 1}]
# Output average count for unique objects in the last second:  {'person': 2, 'motorcycle': 2, 'car': 1, 'snowboard': 1}
# ------------END OF A SECOND --------------
# SECOND :  211
# Array for the outputs of each frame  [[{'name': 'motorcycle', 'percentage_probability': 81.13, 'box_points': [3, 130, 59, 186]}, {'name': 'person', 'percentage_probability': 79.24, 'box_points': [85, 173, 110, 208]}, {'name': 'car', 'percentage_probability': 70.77, 'box_points': [201, 65, 261, 111]}, {'name': 'person', 'percentage_probability': 58.2, 'box_points': [117, 87, 167, 153]}]]
# Array for output count for unique objects in each frame :  [{'motorcycle': 1, 'person': 2, 'car': 1}]
# Output average count for unique objects in the last second:  {'motorcycle': 1, 'person': 2, 'car': 1}
# ------------END OF A SECOND --------------
# SECOND :  212
# Array for the outputs of each frame  [[{'name': 'person', 'percentage_probability': 90.79, 'box_points': [72, 176, 97, 208]}, {'name': 'person', 'percentage_probability': 81.88, 'box_points': [132, 85, 158, 154]}, {'name': 'motorcycle', 'percentage_probability': 79.29, 'box_points': [3, 129, 59, 186]}, {'name': 'car', 'percentage_probability': 70.83, 'box_points': [201, 65, 261, 111]}]]
# Array for output count for unique objects in each frame :  [{'person': 2, 'motorcycle': 1, 'car': 1}]
# Output average count for unique objects in the last second:  {'person': 2, 'motorcycle': 1, 'car': 1}
# ------------END OF A SECOND --------------
# SECOND :  213
# Array for the outputs of each frame  [[{'name': 'person', 'percentage_probability': 87.62, 'box_points': [117, 86, 149, 149]}, {'name': 'motorcycle', 'percentage_probability': 75.28, 'box_points': [5, 132, 62, 186]}, {'name': 'car', 'percentage_probability': 71.77, 'box_points': [200, 66, 261, 111]}, {'name': 'person', 'percentage_probability': 65.76, 'box_points': [34, 176, 74, 209]}, {'name': 'motorcycle', 'percentage_probability': 57.95, 'box_points': [139, 85, 167, 126]}, {'name': 'car', 'percentage_probability': 54.34, 'box_points': [168, 53, 233, 84]}, {'name': 'horse', 'percentage_probability': 52.6, 'box_points': [0, 88, 18, 136]}, {'name': 'person', 'percentage_probability': 50.07, 'box_points': [21, 124, 55, 167]}]]
# Array for output count for unique objects in each frame :  [{'person': 3, 'motorcycle': 2, 'car': 2, 'horse': 1}]
# Output average count for unique objects in the last second:  {'person': 3, 'motorcycle': 2, 'car': 2, 'horse': 1}
# ------------END OF A SECOND --------------
# SECOND :  214
# Array for the outputs of each frame  [[{'name': 'person', 'percentage_probability': 89.81, 'box_points': [113, 90, 134, 145]}, {'name': 'motorcycle', 'percentage_probability': 77.12, 'box_points': [3, 131, 61, 186]}, {'name': 'car', 'percentage_probability': 69.67, 'box_points': [200, 65, 262, 111]}, {'name': 'motorcycle', 'percentage_probability': 66.7, 'box_points': [132, 96, 163, 128]}, {'name': 'car', 'percentage_probability': 61.54, 'box_points': [167, 52, 234, 85]}, {'name': 'person', 'percentage_probability': 60.38, 'box_points': [1, 98, 20, 140]}, {'name': 'person', 'percentage_probability': 54.29, 'box_points': [19, 48, 31, 91]}, {'name': 'car', 'percentage_probability': 51.24, 'box_points': [190, 51, 233, 71]}]]
# Array for output count for unique objects in each frame :  [{'person': 3, 'motorcycle': 2, 'car': 3}]
# Output average count for unique objects in the last second:  {'person': 3, 'motorcycle': 2, 'car': 3}
# ------------END OF A SECOND --------------
# SECOND :  215
# Array for the outputs of each frame  [[{'name': 'person', 'percentage_probability': 91.33, 'box_points': [97, 81, 121, 139]}, {'name': 'motorcycle', 'percentage_probability': 83.58, 'box_points': [121, 89, 162, 127]}, {'name': 'motorcycle', 'percentage_probability': 81.02, 'box_points': [5, 129, 62, 187]}, {'name': 'car', 'percentage_probability': 66.03, 'box_points': [201, 65, 261, 111]}, {'name': 'car', 'percentage_probability': 61.11, 'box_points': [167, 52, 234, 85]}]]
# Array for output count for unique objects in each frame :  [{'person': 1, 'motorcycle': 2, 'car': 2}]
# Output average count for unique objects in the last second:  {'person': 1, 'motorcycle': 2, 'car': 2}
# ------------END OF A SECOND --------------
